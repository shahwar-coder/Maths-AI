# %%
context = '''
• Historical biopsy data from Wisconsin is available, with doctor-verified tumor diagnoses.
• Each record contains measured characteristics of cell nuclei from breast tissue.
• Goal is to automatically flag suspicious (Malignant) tumor cases.
• Task is to build a Logistic Regression classifier from scratch.
• Model predicts the probability that a tumor is Malignant.
• Only NumPy, Pandas, and Matplotlib are allowed.
• Scikit-Learn is strictly prohibited for model building and data splitting.
'''
