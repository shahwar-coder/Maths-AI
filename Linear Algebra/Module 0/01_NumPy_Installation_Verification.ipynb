# %% [markdown]
# # 📦 NumPy Installation & Verification (ai-maths Environment)
#
# This document records the exact steps followed to install NumPy and verify that it is correctly available inside a Python virtual environment.
#
# ---
#
# ## 1️⃣ Activate the Virtual Environment
#
# ```bash
# source ai-maths/bin/activate
# ```
#
# **What this does:**
# - Activates the `ai-maths` virtual environment
# - Ensures all Python and pip commands now point to this environment
# - Terminal prompt changes to show `(ai-maths)`
#
# ---
#
# ## 2️⃣ Install NumPy Using pip
#
# ```bash
# pip install numpy
# ```
#
# **What this does:**
# - Downloads NumPy compatible with the active Python version
# - Installs it inside the `ai-maths` environment
# - Does NOT install a system-wide package
#
# **Observed result:**
# - NumPy was successfully installed
# - Version installed: `numpy 2.3.5`
#
# ---
#
# ## 3️⃣ pip Installation Confirmation
#
# After installation, pip showed:
#
# ```text
# Successfully installed numpy-2.3.5
# ```
#
# **Meaning:**
# - Installation completed without errors
# - NumPy is now present in the environment’s `site-packages`
#
# ---
#
# ## 4️⃣ Attempted (Incorrect) Verification Method
#
# ```bash
# which numpy
# ```
#
# **Result:**
# ```text
# numpy not found
# ```
#
# **Why this happens:**
# - `numpy` is NOT a command-line executable
# - `which` only works for shell commands (like `python`, `pip`, `git`)
# - Python libraries cannot be found using `which`
#
# ✅ This behavior is expected and NOT an error.
#
# ---
#
# ## 5️⃣ Correct Verification Method (Recommended)
#
# ```bash
# python -c "import numpy; print(numpy.__version__)"
# ```
#
# **What this does:**
# - Launches Python from the active environment
# - Imports NumPy
# - Prints the installed NumPy version
#
# **Expected output:**
# ```text
# 2.3.5
# ```
#
# This confirms NumPy is installed and usable.
#
# ---
#
# ## 6️⃣ Verify via pip (Optional Check)
#
# ```bash
# pip show numpy
# ```
#
# **What this does:**
# - Displays package metadata
# - Confirms installation location
# - Shows version and dependency info
#
# **Key field to check:**
# - `Location:` should point inside the `ai-maths` environment
#
# ---
#
# ## 7️⃣ Python REPL Verification (Optional)
#
# ```bash
# python
# ```
#
# Inside Python:
#
# ```python
# import numpy as np
# np.__version__
# ```
#
# Exit Python:
#
# ```bash
# exit()
# ```
#
# **Purpose:**
# - Confirms NumPy works interactively
# - Useful for notebooks and experiments
#
# ---
#
# ## ✅ Final Conclusion
#
# - NumPy is correctly installed
# - Installation happened inside the `ai-maths` virtual environment
# - `which numpy` is NOT a valid verification method
# - Correct checks are:
#   - `import numpy`
#   - `pip show numpy`
#
# ---
#
# ## 📌 Key Takeaway
#
# > **Python packages are verified using Python, not shell tools.**
#
# Use:
# - `import package_name`
# - NOT `which package_name`
#
# ---
