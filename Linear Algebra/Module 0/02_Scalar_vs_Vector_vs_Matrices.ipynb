# %%
'''
Q1. What is a scalar in simple words?
Ans. A scalar is just ONE number — a single value with no direction or list.
'''
# Example
learning_rate = 0.001
loss = 2.31
accuracy = 0.98


'''
Q2. Where are scalars used in AI systems?
Ans. Scalars are used for values like loss, accuracy, learning rate, temperature, etc.
'''
# Example
# During training:
# loss = 1.87
# learning_rate = 0.0005


'''
Q3. What is a vector?
Ans. A vector is an ordered list of numbers (1-D data).
'''
# Example
features = [2, 4, 6]
probabilities = [0.1, 0.7, 0.2]


'''
Q4. How are vectors used in AI?
Ans. Vectors represent features, embeddings, or neuron weights.
'''
# Example
# One word embedding (simplified)
word_embedding = [0.12, -0.44, 0.89, 0.03]


'''
Q5. What is a matrix?
Ans. A matrix is a table of numbers made of rows and columns (2-D data).
'''
# Example
matrix = [
    [1, 2, 3],
    [4, 5, 6]
]


'''
Q6. How are matrices used in AI?
Ans. Matrices store datasets, neural network weights, and attention scores.
'''
# Example
# Dataset:
# Rows = samples, Columns = features
dataset = [
    [170, 65, 1],   # height, weight, label
    [160, 55, 0],
    [180, 75, 1]
]


'''
Q7. Can you relate scalar, vector, and matrix to images?
Ans. Yes. Pixel brightness is a scalar, one pixel’s RGB values form a vector, and a full image is a matrix.
'''
# Example
# One pixel (RGB)
pixel = [255, 128, 64]   # vector

# Image (many pixels)
image = [
    [[255,0,0], [0,255,0]],
    [[0,0,255], [255,255,255]]
]

# %% [markdown]
# ### Scaler

# %%
import numpy as np

learning_rate = 0.001 # Scalar
loss = np.array(2.31) # NumPy Scalar

print(f"""Learning Rate: {learning_rate}, Type: {type(learning_rate)}")
print(f"Loss: {loss}, Type: {type(loss)}")""")

# 📌 AI intuition:
# Scalars are used to control or measure things (how fast we learn, how wrong we are).
# Out:
# Learning Rate: 0.001, Type: <class 'float'>")
# print(f"Loss: 2.31, Type: <class 'numpy.ndarray'>")

# %% [markdown]
# ### Scaler in AI

# %%
temperature = 0.7     # Controls randomness in LLM output
epochs = 10           # Number of training cycles

# 📌 Rule of thumb:
# If it’s one value, it’s a scalar.

# %% [markdown]
# ### Vector

# %%
# Python list (conceptual vector)
features = [2, 4, 6]

# NumPy vector (real math vector)
features_np = np.array([2, 4, 6])

print(features_np.shape)   # (3,)

# 📌 A vector is an ordered list of numbers representing 1-D data.
# Out:
# (3,)

# %% [markdown]
# ### Vector in AI

# %%
# Word embedding (simplified)
word_embedding = np.array([0.12, -0.44, 0.89, 0.03])

print(word_embedding.shape)   # (4,)

# 📌 In AI, vectors represent features, embeddings, or neuron weights.
# 📌 AI intuition:
# Vectors are how AI understands meaning (words, images, users, sounds).
# Out:
# (4,)

# %% [markdown]
# ### NumPy Matrix

# %%
matrix = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

print(matrix.shape)   # (2, 3)

# 📌 A matrix is a 2-D array of numbers representing rows and columns.
# Out:
# (2, 3)

# %% [markdown]
# ### Matrix in AI

# %%
dataset = np.array([
    [170, 65, 1],
    [160, 55, 0],
    [180, 75, 1]
])

print(dataset.shape)   # (3, 3)

# 📌 In AI, matrices store datasets, neural network weights, and attention scores.

# 📌 AI intuition:
# Rows → samples
# Columns → features
# Neural networks = matrix multiplications
# Out:
# (3, 3)

# %% [markdown]
# ### Image Relation
# > Scalar → Vector → Matrix → Tensor

# %%
# Scalar (pixel intensity in grayscale)
pixel_intensity = 128

# Vector (RGB pixel)
pixel_rgb = np.array([255, 128, 64])

# Matrix (grayscale image: height × width)
grayscale_image = np.array([
    [0, 255],
    [128, 64]
])

# Tensor (color image: height × width × channels)
image = np.array([
    [[255,0,0], [0,255,0]],
    [[0,0,255], [255,255,255]]
])

print(image.shape)   # (2, 2, 3)

# Key Idea: Images are not matrices, they are 3-D tensors.
# Out:
# (2, 2, 3)
